# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Web Scraping Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab you will be able to:

# %% [markdown]
# * Download a webpage using requests module
# * Scrape all links from a web page
# * Scrape all image urls from a web page
# * Scrape data from html tables

# %% [markdown]
# ## Scrape www.ibm.com

# %% [markdown]
# Import the required modules and functions

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %% [markdown]
# Download the contents of the web page

# %%
url = "http://www.ibm.com"

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %% [markdown]
# Create a soup object using the class BeautifulSoup

# %%
soup = BeautifulSoup(data,"html5lib")  # create a soup object using the variable 'data'

# %% [markdown]
# Scrape all links

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests
# !pip3 install html5lib

url = "http://www.ibm.com";

data  = requests.get(url).text;
soup = BeautifulSoup(data, );

#print(data)


for link in soup.find_all('a'):  # in html anchor/link is represented by the tag <a>
    print(link.get('href'))
# Out:
# Requirement already satisfied: html5lib in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (1.1)
# Requirement already satisfied: six>=1.9 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from html5lib) (0.5.1)
# https://www.ibm.com/thought-leadership/institute-business-value/en-us/report/2023-banking-financial-markets-outlook?lnk=dehpv18l1
# #3171776
# #3171802
# #3171808
# #3171812
# #3171828
# #3171834
# https://de.newsroom.ibm.com/2023-02-01-IBM-und-NASA-erforschen-gemeinsam-mithilfe-von-KI-die-Auswirkungen-des-Klimawandels?lnk=dehpv18nf1
# https://research.ibm.com/blog/ibm-nasa-foundation-models?lnk=dehpv18nf2
# /de-de/about
# #tab_3171780
# #tab_3171784
# #tab_3171788
# #tab_3171792
# #tab_3171796
# #tab_3171800
# https://www.ibm.com/consulting/de-de
# https://www.ibm.com/de-de/consulting/strategy
# /de-de/consulting/ibmix?lnk=flathl
# https://www.ibm.com/de-de/consulting/technology
# /de-de/services/operations-consulting?lnk=flathl
# /strategic-partnerships?lnk=flathl
# /de-de/case-studies/iberdrola
# https://www.ibm.com/careers/de-de/
# https://www.ibm.com/careers/de-de/
# https://research.ibm.com
# https://research.ibm.com
# https://www.ibm.com/impact
# https://www.ibm.com/impact
# /de-de/about
# https://www.ibm.com/de-de/products/?lnk=fdi
# https://www.ibm.com/de-en/products/trials?lnk=STW_DE_HPF_THP_FT_TL&lnk2=goto_THP
# https://www.ibm.com/de-de/products/?lnk=hmmpr
# https://www.ibm.com/de-de/services?lnk=fdi-dede
# https://www.ibm.com/de-de/industries
# https://www.ibm.com/ibm/clientreference/us/en/?lnk=fdi-dede
# https://www.ibm.com/de-de/events?lnk=fdi-dede
# https://www.ibm.com/blogs/think/de-de/?lnk=fdi-dede
# https://www.ibm.com/de-de/financing
# https://developer.ibm.com/?lnk=fif-dede
# https://www.ibm.com/de-de/partnerworld/public
# https://www.ibm.com/partners/start/?lnk=fif-dede
# https://www.ibm.com/consulting/de-de/
# https://www.ibm.com/mysupport/s/?language=en_US
# https://www.ibm.com/partnerworld/public
# https://myibm.ibm.com/dashboard/?lnk=mmi_dede
# https://www.ibm.com/ibm/clientcenter/walldorf?lnk=fab-dede
# https://www.ibm.com/de-de/employment/?lnk=fab-dede
# https://de.newsroom.ibm.com/
# https://www.ibm.com/investor/?lnk=fab-dede
# https://www.ibm.com/de-de/about?lnk=fab-dede
# https://www.ibm.com/ibm/clientcenter/boeblingen/
# https://www.ibm.com/watson/munich-center
# https://www.ibm.com/de-de/about?lnk=flg-cont-dede
# https://www.ibm.com/de-de/privacy?lnk=flg-priv-dede
# https://www.ibm.com/de-de/legal?lnk=flg-tous-dede
# https://www.ibm.com/able/?lnk=flg-able-dede
# https://www.ibm.com/de-de/about?lnk=flg
# #

# %% [markdown]
# Scrape  all images

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link.get('src'))
# Out:
# //1.cms.s81c.com/sites/default/files/2022-11-16/XLG%20-%20IBM%20Consulting%20-%20Overview.jpg
# //1.cms.s81c.com/sites/default/files/2022-11-16/XLG%20-%20IBM%20Consulting%20-%20Strategy.jpg
# //1.cms.s81c.com/sites/default/files/2022-11-16/XLG%20-%20IBM%20Consulting%20-%20Experience.jpg
# //1.cms.s81c.com/sites/default/files/2022-11-16/XLG%20-%20IBM%20Consulting%20-%20Technology.jpg
# //1.cms.s81c.com/sites/default/files/2022-11-16/XLG%20-%20IBM%20Consulting%20-%20Operations.jpg
# //1.cms.s81c.com/sites/default/files/2022-11-16/XLG%20-%20IBM%20Consulting%20-%20Partners.jpg
# //1.cms.s81c.com/sites/default/files/2022-11-16/XLG%20-%20Inside%20IBM%20-%20IBM%20Careers.jpg
# //1.cms.s81c.com/sites/default/files/2022-11-16/XLG%20-%20Inside%20IBM%20-%20Research%20Labs.jpg
# //1.cms.s81c.com/sites/default/files/2022-11-16/XLG%20-%20Inside%20IBM%20-%20Corporate%20Social%20Responsibility.jpg

# %% [markdown]
# ## Scrape data from html tables

# %%
#The below url contains a html table with data about colors and color codes.

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# Before proceeding to scrape a web site, you need to examine the contents, and the way data is organized on the website. Open the above url in your browser and check how many rows and columns are there in the color table.

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %%
soup = BeautifulSoup(data,"html5lib")

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>

# %%
#Get all rows from the table

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html";
data  = requests.get(url).text;
soup = BeautifulSoup(data,"html5lib");
table = soup.find('table');

for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].getText() # store the value in column 3 as color_name
    color_code = cols[3].getText() # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Input In [26], in <cell line: 5>()
#       3 url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html";
#       4 data  = requests.get(url).text;
# ----> 5 soup = BeautifulSoup(data,"html5lib");
#       6 table = soup.find('table');
#       8 for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
#       9     # Get all columns in each row.
#
# File /opt/conda/envs/Python-3.10/lib/python3.10/site-packages/bs4/__init__.py:248, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     246     builder_class = builder_registry.lookup(*features)
#     247     if builder_class is None:
# --> 248         raise FeatureNotFound(
#     249             "Couldn't find a tree builder with the features you "
#     250             "requested: %s. Do you need to install a parser library?"
#     251             % ",".join(features))
#     253 # At this point either we have a TreeBuilder instance in
#     254 # builder, or we have a builder_class that we can instantiate
#     255 # with the remaining **kwargs.
#     256 if builder is None:
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: html5lib. Do you need to install a parser library?

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-10-17  | 0.1  | Ramesh Sannareddy  |  Created initial version of the lab |

# %% [markdown]
#  Copyright &copy; 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01).
